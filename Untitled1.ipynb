# %%
import pandas as pd

# %%
from bokeh.plotting import figure, output_notebook, ColumnDataSource

# %%
from bokeh.io import show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
x = [1, 2, 3, 4, 5]

# %%
y1 = [6, 7, 2, 4, 5]

# %%
y2 = [2, 3, 4, 5, 6]

# %%
y3 = [4, 5, 5, 7, 2]

# %%
p = figure(title="Multiple line example", x_axis_label="x", y_axis_label="y")

# %%
p.line(x, y1, legend_label="Temp.", line_color="blue", line_width=2)
# Out:
# GlyphRenderer(id='1039', ...)

# %%
p.line(x, y2, legend_label="Rate", line_color="red", line_width=2)
# Out:
# GlyphRenderer(id='1058', ...)

# %%
show(p)
# Out:
#   <div class="bk-root" id="1a169b63-2ad2-4b5c-a20f-758225affa4a" data-root-id="1003"></div>
